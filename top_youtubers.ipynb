# %%
import pandas as pd

# %%
# define path
data_path = '/content/Youtuber.csv'

# read data from csv file
df_hr = pd.read_csv(data_path)

df_hr
# Out:
#         Rank                Channel Name       Category Subscribers  \
# 0        NaN                         NaN            NaN         NaN
# 1        1.0                    T-Series  Music & Dance      258.4M
# 2        2.0                     MrBeast    Video games      236.1M
# 3        3.0  Cocomelon - Nursery Rhymes      Education      171.4M
# 4        4.0                   SET India            NaN      167.1M
# ...      ...                         ...            ...         ...
# 1041   996.0                   BBC Earth            NaN       12.5M
# 1042   997.0                Jamie Nyland      Animation       12.5M
# 1043   998.0              janin al chair            NaN       12.5M
# 1044   999.0                 Myke Towers  Music & Dance       12.5M
# 1045  1000.0                   HikakinTV          Humor       12.5M
#
#             Country Average Views Average Likes Average Comments Content Type
# ...

# %%
# use head() to view top 5 rows
df_hr.head()
# Out:
#    Rank                Channel Name       Category Subscribers        Country  \
# 0   NaN                         NaN            NaN         NaN            NaN
# 1   1.0                    T-Series  Music & Dance      258.4M          India
# 2   2.0                     MrBeast    Video games      236.1M  United States
# 3   3.0  Cocomelon - Nursery Rhymes      Education      171.4M            NaN
# 4   4.0                   SET India            NaN      167.1M          India
#
#   Average Views Average Likes Average Comments Content Type
# 0           NaN           NaN              NaN          NaN
# 1        135.2K          5.6K              223          NaN
# 2          104M            4M              74K        Humor
# 3          5.1M         57.1K                0          NaN
# 4         27.9K           996                7          NaN

# %%
# use tail() to view last 5 rows
df_hr.tail()
# Out:
#         Rank    Channel Name       Category Subscribers        Country  \
# 1041   996.0       BBC Earth            NaN       12.5M  United States
# 1042   997.0    Jamie Nyland      Animation       12.5M  United States
# 1043   998.0  janin al chair            NaN       12.5M         Mexico
# 1044   999.0     Myke Towers  Music & Dance       12.5M       Colombia
# 1045  1000.0       HikakinTV          Humor       12.5M          Japan
#
#      Average Views Average Likes Average Comments Content Type
# 1041         80.3K          1.7K               79          NaN
# 1042         66.7K          2.5K              104        Humor
# 1043          1.4M        146.1K              485          NaN
# 1044          8.3K           485                8          NaN
# 1045        703.2K         25.3K              312          NaN

# %%
# Check dataframe shape


df_hr.shape
# Out:
# (1046, 9)

# %%
# extract dataframe index

df_hr.index
# Out:
# RangeIndex(start=0, stop=1046, step=1)

# %%
# extract  columns

df_hr.columns
# Out:
# Index(['Rank', 'Channel Name', 'Category', 'Subscribers', 'Country',
#        'Average Views', 'Average Likes', 'Average Comments', 'Content Type'],
#       dtype='object')

# %%
# get column types

df_hr.dtypes
# Out:
# Rank                float64
# Channel Name         object
# Category             object
# Subscribers          object
# Country              object
# Average Views        object
# Average Likes        object
# Average Comments     object
# Content Type         object
# dtype: object

# %%
# Check for missing values
missing_values = df_hr.isnull().sum()

# Display the number of missing values in each column
print("Missing values in each column:")
print(missing_values)
# Out:
# Missing values in each column:
# Rank                  1
# Channel Name          1
# Category            351
# Subscribers           1
# Country             193
# Average Views         1
# Average Likes         1
# Average Comments      1
# Content Type        711
# dtype: int64

# %%
# Display descriptive statistics for numerical columns
print(df_hr.describe())
# Out:
#               Rank
# count  1045.000000
# mean    521.055502
# std     298.709262
# min       1.000000
# 25%     262.000000
# 50%     523.000000
# 75%     784.000000
# max    1000.000000

# %%
# Count the number of unique categories
num_unique_categories = df_hr['Category'].nunique()
print("Number of unique categories:", num_unique_categories)
# Out:
# Number of unique categories: 23

# %%
# Find the most common content type
most_common_content_type = df_hr['Content Type'].mode()[0]
print("Most common content type:", most_common_content_type)
# Out:
# Most common content type: Humor

# %%
import matplotlib.pyplot as plt

# Count the number of channels in each category
category_counts = df_hr['Category'].value_counts()

# Plot the bar plot
plt.figure(figsize=(10, 6))
category_counts.plot(kind='bar')
plt.title('Number of Channels in Each Category')
plt.xlabel('Category')
plt.ylabel('Number of Channels')
plt.xticks(rotation=90, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# -The youtube channels related to music & dance are the most
# + While fashion stood at the last

# %%
df_hr
# Out:
#         Rank                Channel Name       Category Subscribers  \
# 0        NaN                         NaN            NaN         NaN
# 1        1.0                    T-Series  Music & Dance      258.4M
# 2        2.0                     MrBeast    Video games      236.1M
# 3        3.0  Cocomelon - Nursery Rhymes      Education      171.4M
# 4        4.0                   SET India            NaN      167.1M
# ...      ...                         ...            ...         ...
# 1041   996.0                   BBC Earth            NaN       12.5M
# 1042   997.0                Jamie Nyland      Animation       12.5M
# 1043   998.0              janin al chair            NaN       12.5M
# 1044   999.0                 Myke Towers  Music & Dance       12.5M
# 1045  1000.0                   HikakinTV          Humor       12.5M
#
#             Country Average Views Average Likes Average Comments Content Type
# ...

# %% [markdown]
# **Data set cleaning**

# %%
# Drop rows with missing values in crucial columns
df_hr = df_hr.drop(columns=['Rank', 'Channel Name', 'Subscribers'], axis=1)

# %%
df_hr
# Out:
#            Category        Country Average Views Average Likes  \
# 0               NaN            NaN           NaN           NaN
# 1     Music & Dance          India        135.2K          5.6K
# 2       Video games  United States          104M            4M
# 3         Education            NaN          5.1M         57.1K
# 4               NaN          India         27.9K           996
# ...             ...            ...           ...           ...
# 1041            NaN  United States         80.3K          1.7K
# 1042      Animation  United States         66.7K          2.5K
# 1043            NaN         Mexico          1.4M        146.1K
# 1044  Music & Dance       Colombia          8.3K           485
# 1045          Humor          Japan        703.2K         25.3K
#
#      Average Comments Content Type
# 0                 NaN          NaN
# 1                 223          NaN
# 2                 74K        Humor
# 3                   0          NaN
# ...

# %%
# Define numeric columns
numeric_cols = ['Average Views', 'Average Likes', 'Average Comments']

# %%
# Convert numeric columns to numeric types
df_hr[numeric_cols] = df_hr[numeric_cols].apply(pd.to_numeric, errors='coerce')

# %%
# Handle missing values in 'Category', 'Country', and 'Content Type'
# Fill missing values in 'Category' with a placeholder value "Unknown"
df_hr['Category'] = df_hr['Category'].fillna("Unknown")

# %%
# Fill missing values in 'Country' with a placeholder value "Unknown"
df_hr['Country'] = df_hr['Country'].fillna("Unknown")

# %%
# Fill missing values in 'Content Type' with a placeholder value "Unknown"
df_hr['Content Type'] = df_hr['Content Type'].fillna("Unknown")

df_hr
# Out:
#            Category        Country  Average Views  Average Likes  \
# 0           Unknown        Unknown            NaN            NaN
# 1     Music & Dance          India            NaN            NaN
# 2       Video games  United States            NaN            NaN
# 3         Education        Unknown            NaN            NaN
# 4           Unknown          India            NaN          996.0
# ...             ...            ...            ...            ...
# 1041        Unknown  United States            NaN            NaN
# 1042      Animation  United States            NaN            NaN
# 1043        Unknown         Mexico            NaN            NaN
# 1044  Music & Dance       Colombia            NaN          485.0
# 1045          Humor          Japan            NaN            NaN
#
#       Average Comments Content Type
# 0                  NaN      Unknown
# 1                223.0      Unknown
# 2                  NaN        Humor
# 3                  0.0      Unknown
# ...

# %%
# Inpute missing values with the mean for numeric columns
df_hr[['Average Views', 'Average Likes', 'Average Comments']] = df_hr[['Average Views', 'Average Likes', 'Average Comments']].apply(lambda x: x.fillna(x.mean()))
df_hr
# Out:
#            Category        Country  Average Views  Average Likes  \
# 0           Unknown        Unknown         127.66     297.008902
# 1     Music & Dance          India         127.66     297.008902
# 2       Video games  United States         127.66     297.008902
# 3         Education        Unknown         127.66     297.008902
# 4           Unknown          India         127.66     996.000000
# ...             ...            ...            ...            ...
# 1041        Unknown  United States         127.66     297.008902
# 1042      Animation  United States         127.66     297.008902
# 1043        Unknown         Mexico         127.66     297.008902
# 1044  Music & Dance       Colombia         127.66     485.000000
# 1045          Humor          Japan         127.66     297.008902
#
#       Average Comments Content Type
# 0           135.731762      Unknown
# 1           223.000000      Unknown
# 2           135.731762        Humor
# 3             0.000000      Unknown
# ...

# %% [markdown]
# **Distribution of data**

# %%
import seaborn as sns

# %% [markdown]
# **What is the distribution of channels based on content type within each country?**

# %%
content_type_counts = df_hr['Content Type'].value_counts()

# %%
# Plot the bar plot
plt.figure(figsize=(10, 6))
content_type_counts.plot(kind='bar')
plt.title('Distribution of Content Types')
plt.xlabel('Content Type')
plt.ylabel('Number of Channels')
plt.xticks(rotation=90, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# **What are the top 5 countries with the most channels?**

# %%
# Count the number of channels in each country
country_counts = df_hr['Country'].value_counts().head(5)

# %%
# Plot the bar plot
plt.figure(figsize=(10, 6))
country_counts.plot(kind='bar')
plt.title('Top 5 Countries with the Most Channels')
plt.xlabel('Country')
plt.ylabel('Number of Channels')
plt.xticks(rotation=90, ha='right')

plt.show()

# %%
df_hr
# Out:
#            Category        Country  Average Views  Average Likes  \
# 0           Unknown        Unknown         127.66     297.008902
# 1     Music & Dance          India         127.66     297.008902
# 2       Video games  United States         127.66     297.008902
# 3         Education        Unknown         127.66     297.008902
# 4           Unknown          India         127.66     996.000000
# ...             ...            ...            ...            ...
# 1041        Unknown  United States         127.66     297.008902
# 1042      Animation  United States         127.66     297.008902
# 1043        Unknown         Mexico         127.66     297.008902
# 1044  Music & Dance       Colombia         127.66     485.000000
# 1045          Humor          Japan         127.66     297.008902
#
#       Average Comments Content Type
# 0           135.731762      Unknown
# 1           223.000000      Unknown
# 2           135.731762        Humor
# 3             0.000000      Unknown
# ...

# %% [markdown]
# **Conclusion**
# + The United State has most number of youtube channels
# + Youtubers from the filed of music & dance and also movie are the most in above distributions
